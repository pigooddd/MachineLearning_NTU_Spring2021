# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('C:/Users/user/Desktop/研究所/程式/ML/font_data.npy')

fig = plt.figure(figsize=(10,10), dpi=80)
plt.subplots_adjust(0.05,0.05,0.95,0.95,0.1,0.1)
for i in range(100):
    plt.subplot(10,10,i+1)
    plt.axis('off')
    plt.imshow(data[np.random.randint(4808)], cmap='Greys')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.load('font_data.npy')
x_train = x_train/127.5-1.

latent_size = 128
img_shape = (48,48)

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

discriminator = Sequential()
discriminator.add(Reshape((np.prod(img_shape),),input_shape=img_shape))
discriminator.add(Dense(512))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))
discriminator.add(Dense(256))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy',
                      optimizer=Adam(0.0002, 0.5),
                      metrics=['accuracy'])

generator = Sequential()
generator.add(Dense(256, input_dim=latent_size))
generator.add(LeakyReLU())
generator.add(BatchNormalization())
generator.add(Dense(512))
generator.add(LeakyReLU())
generator.add(BatchNormalization())
generator.add(Dense(1024))
generator.add(LeakyReLU())
generator.add(BatchNormalization())
generator.add(Dense(np.prod(img_shape), activation='tanh'))
generator.add(Reshape(img_shape))

noise = Input(shape=(latent_size,))
img = generator(noise)
discriminator.trainable = False
validity = discriminator(img)
combined = Model(noise, validity)
combined.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

noise_test = np.random.randn(100, latent_size)
batch_size = 64
for epoch in range(20001):
    
    imgs_real = x_train[np.random.randint(0, len(x_train), batch_size)]
    
    noise = np.random.randn(batch_size, latent_size)
    imgs_fake = generator.predict(noise)

    dis_loss_real = discriminator.train_on_batch(imgs_real, np.ones((batch_size,1)))
    dis_loss_fake = discriminator.train_on_batch(imgs_fake, np.zeros((batch_size,1)))
    dis_loss = np.add(dis_loss_real,dis_loss_fake)*0.5

    noise = np.random.randn(batch_size, latent_size)
    gen_loss = combined.train_on_batch(noise, np.ones((batch_size,1)))
                                       
    print("Epoch: %d, discriminator(loss: %.3f, acc.: %.2f%%), generator(loss: %.3f)" %
          (epoch, dis_loss[0], dis_loss[1]*100., gen_loss))

    if epoch % 200 == 0:
        imgs_fake = generator.predict(noise_test)
                                       
        fig = plt.figure(figsize=(10,10), dpi=80)
        plt.subplots_adjust(0.05,0.05,0.95,0.95,0.1,0.1)
        for i in range(100):
            plt.subplot(10,10,i+1)
            plt.axis('off')
            plt.imshow(imgs_fake[i], cmap='Greys')
        fig.suptitle('epoch: %05d' % epoch, color='Blue', fontsize=16)
        fig.savefig("%05d.jpg" % epoch)
        plt.close()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Epoch: 0, discriminator(loss: 0.887, acc.: 53.91%), generator(loss: 1.016)
# Epoch: 1, discriminator(loss: 0.255, acc.: 98.44%), generator(loss: 0.968)
# Epoch: 2, discriminator(loss: 0.226, acc.: 100.00%), generator(loss: 0.834)
# Epoch: 3, discriminator(loss: 0.179, acc.: 100.00%), generator(loss: 0.861)
# Epoch: 4, discriminator(loss: 0.142, acc.: 100.00%), generator(loss: 0.893)
# Epoch: 5, discriminator(loss: 0.122, acc.: 100.00%), generator(loss: 0.880)
# Epoch: 6, discriminator(loss: 0.111, acc.: 100.00%), generator(loss: 0.891)
# Epoch: 7, discriminator(loss: 0.094, acc.: 100.00%), generator(loss: 0.837)
# Epoch: 8, discriminator(loss: 0.090, acc.: 100.00%), generator(loss: 0.854)
# Epoch: 9, discriminator(loss: 0.082, acc.: 100.00%), generator(loss: 0.775)
# Epoch: 10, discriminator(loss: 0.070, acc.: 100.00%), generator(loss: 0.866)
# Epoch: 11, discriminator(loss: 0.071, acc.: 100.00%), generator(loss: 0.786)
# Epoch: 12, discriminator(loss: 0.060, acc.: 100.00%), generator(loss: 0.821)
# Epoch: 13, discriminator(loss: 0.068, acc.: 100.00%), generator(loss: 0.854)
# Epoch: 14, discriminator(loss: 0.062, acc.: 100.00%), generator(loss: 0.828)
# Epoch: 15, discriminator(loss: 0.062, acc.: 100.00%), generator(loss: 0.765)
# Epoch: 16, discriminator(loss: 0.057, acc.: 100.00%), generator(loss: 0.762)
# Epoch: 17, discriminator(loss: 0.068, acc.: 100.00%), generator(loss: 0.923)
# Epoch: 18, discriminator(loss: 0.064, acc.: 100.00%), generator(loss: 0.865)
# Epoch: 19, discriminator(loss: 0.065, acc.: 100.00%), generator(loss: 0.882)
# Epoch: 20, discriminator(loss: 0.057, acc.: 100.00%), generator(loss: 0.837)
# Epoch: 21, discriminator(loss: 0.075, acc.: 100.00%), generator(loss: 0.814)
# Epoch: 22, discriminator(loss: 0.064, acc.: 100.00%), generator(loss: 0.799)
# Epoch: 23, discriminator(loss: 0.069, acc.: 100.00%), generator(loss: 0.836)
# Epoch: 24, discriminator(loss: 0.067, acc.: 100.00%), generator(loss: 0.763)
# Epoch: 25, discriminator(loss: 0.064, acc.: 100.00%), generator(loss: 0.864)
# Epoch: 26, discriminator(loss: 0.072, acc.: 100.00%), generator(loss: 0.934)
# Epoch: 27, discriminator(loss: 0.084, acc.: 100.00%), generator(loss: 0.871)
# Epoch: 28, discriminator(loss: 0.089, acc.: 100.00%), generator(loss: 0.978)
# Epoch: 29, discriminator(loss: 0.080, acc.: 100.00%), generator(loss: 1.000)
# Epoch: 30, discriminator(loss: 0.076, acc.: 100.00%), generator(loss: 1.044)
# Epoch: 31, discriminator(loss: 0.082, acc.: 100.00%), generator(loss: 1.222)
# Epoch: 32, discriminator(loss: 0.091, acc.: 100.00%), generator(loss: 1.214)
# Epoch: 33, discriminator(loss: 0.100, acc.: 100.00%), generator(loss: 1.334)
# Epoch: 34, discriminator(loss: 0.091, acc.: 100.00%), generator(loss: 1.401)
# Epoch: 35, discriminator(loss: 0.088, acc.: 100.00%), generator(loss: 1.322)
# Epoch: 36, discriminator(loss: 0.107, acc.: 99.22%), generator(loss: 1.406)
# Epoch: 37, discriminator(loss: 0.096, acc.: 99.22%), generator(loss: 1.744)
# Epoch: 38, discriminator(loss: 0.094, acc.: 99.22%), generator(loss: 1.745)
# Epoch: 39, discriminator(loss: 0.109, acc.: 100.00%), generator(loss: 1.866)
# Epoch: 40, discriminator(loss: 0.103, acc.: 100.00%), generator(loss: 2.230)
# Epoch: 41, discriminator(loss: 0.109, acc.: 99.22%), generator(loss: 2.045)
# Epoch: 42, discriminator(loss: 0.100, acc.: 100.00%), generator(loss: 2.289)
# Epoch: 43, discriminator(loss: 0.090, acc.: 100.00%), generator(loss: 2.270)
# Epoch: 44, discriminator(loss: 0.084, acc.: 100.00%), generator(loss: 2.270)
# Epoch: 45, discriminator(loss: 0.077, acc.: 100.00%), generator(loss: 2.439)
# Epoch: 46, discriminator(loss: 0.071, acc.: 100.00%), generator(loss: 2.320)
# Epoch: 47, discriminator(loss: 0.077, acc.: 100.00%), generator(loss: 2.846)
# Epoch: 48, discriminator(loss: 0.078, acc.: 99.22%), generator(loss: 2.784)
# Epoch: 49, discriminator(loss: 0.079, acc.: 100.00%), generator(loss: 2.882)
# Epoch: 50, discriminator(loss: 0.067, acc.: 100.00%), generator(loss: 3.048)
# Epoch: 51, discriminator(loss: 0.055, acc.: 100.00%), generator(loss: 3.099)
# Epoch: 52, discriminator(loss: 0.069, acc.: 100.00%), generator(loss: 3.135)
# Epoch: 53, discriminator(loss: 0.054, acc.: 100.00%), generator(loss: 3.197)
# Epoch: 54, discriminator(loss: 0.056, acc.: 100.00%), generator(loss: 3.278)
# Epoch: 55, discriminator(loss: 0.043, acc.: 100.00%), generator(loss: 3.337)
# Epoch: 56, discriminator(loss: 0.054, acc.: 100.00%), generator(loss: 3.528)
# Epoch: 57, discriminator(loss: 0.055, acc.: 100.00%), generator(loss: 3.457)
# Epoch: 58, discriminator(loss: 0.040, acc.: 100.00%), generator(loss: 3.686)
# Epoch: 59, discriminator(loss: 0.042, acc.: 100.00%), generator(loss: 3.729)
# Epoch: 60, discriminator(loss: 0.035, acc.: 100.00%), generator(loss: 3.784)
# Epoch: 61, discriminator(loss: 0.037, acc.: 100.00%), generator(loss: 3.645)
# Epoch: 62, discriminator(loss: 0.058, acc.: 100.00%), generator(loss: 3.567)
# Epoch: 63, discriminator(loss: 0.051, acc.: 100.00%), generator(loss: 3.872)
# Epoch: 64, discriminator(loss: 0.043, acc.: 100.00%), generator(loss: 3.890)
# Epoch: 65, discriminator(loss: 0.047, acc.: 100.00%), generator(loss: 3.791)
# Epoch: 66, discriminator(loss: 0.050, acc.: 100.00%), generator(loss: 3.960)
# Epoch: 67, discriminator(loss: 0.042, acc.: 100.00%), generator(loss: 4.438)
# Epoch: 68, discriminator(loss: 0.036, acc.: 100.00%), generator(loss: 4.461)
# Epoch: 69, discriminator(loss: 0.024, acc.: 100.00%), generator(loss: 4.192)
# Epoch: 70, discriminator(loss: 0.039, acc.: 99.22%), generator(loss: 3.809)
# Epoch: 71, discriminator(loss: 0.032, acc.: 100.00%), generator(loss: 4.228)
# Epoch: 72, discriminator(loss: 0.037, acc.: 100.00%), generator(loss: 4.381)
# Epoch: 73, discriminator(loss: 0.030, acc.: 100.00%), generator(loss: 4.148)
# Epoch: 74, discriminator(loss: 0.028, acc.: 100.00%), generator(loss: 4.196)
# Epoch: 75, discriminator(loss: 0.033, acc.: 100.00%), generator(loss: 4.367)
# Epoch: 76, discriminator(loss: 0.021, acc.: 100.00%), generator(loss: 4.559)
# Epoch: 77, discriminator(loss: 0.030, acc.: 100.00%), generator(loss: 4.202)
# Epoch: 78, discriminator(loss: 0.029, acc.: 100.00%), generator(loss: 4.342)
# Epoch: 79, discriminator(loss: 0.031, acc.: 100.00%), generator(loss: 4.298)
# Epoch: 80, discriminator(loss: 0.033, acc.: 100.00%), generator(loss: 4.307)
# Epoch: 81, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 4.288)
# Epoch: 82, discriminator(loss: 0.033, acc.: 100.00%), generator(loss: 4.254)
# Epoch: 83, discriminator(loss: 0.026, acc.: 100.00%), generator(loss: 4.556)
# Epoch: 84, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 4.707)
# Epoch: 85, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 4.379)
# Epoch: 86, discriminator(loss: 0.022, acc.: 100.00%), generator(loss: 4.722)
# Epoch: 87, discriminator(loss: 0.029, acc.: 99.22%), generator(loss: 4.429)
# Epoch: 88, discriminator(loss: 0.035, acc.: 99.22%), generator(loss: 4.492)
# Epoch: 89, discriminator(loss: 0.034, acc.: 100.00%), generator(loss: 4.585)
# Epoch: 90, discriminator(loss: 0.024, acc.: 100.00%), generator(loss: 4.590)
# Epoch: 91, discriminator(loss: 0.027, acc.: 100.00%), generator(loss: 4.768)
# Epoch: 92, discriminator(loss: 0.024, acc.: 100.00%), generator(loss: 4.677)
# Epoch: 93, discriminator(loss: 0.026, acc.: 100.00%), generator(loss: 4.702)
# Epoch: 94, discriminator(loss: 0.021, acc.: 100.00%), generator(loss: 4.933)
# Epoch: 95, discriminator(loss: 0.017, acc.: 100.00%), generator(loss: 4.804)
# Epoch: 96, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 4.890)
# Epoch: 97, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 5.125)
# Epoch: 98, discriminator(loss: 0.035, acc.: 100.00%), generator(loss: 4.946)
# Epoch: 99, discriminator(loss: 0.017, acc.: 100.00%), generator(loss: 5.164)
# Epoch: 100, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 5.282)
# Epoch: 101, discriminator(loss: 0.020, acc.: 100.00%), generator(loss: 5.435)
# Epoch: 102, discriminator(loss: 0.021, acc.: 100.00%), generator(loss: 5.268)
# Epoch: 103, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 5.138)
# Epoch: 104, discriminator(loss: 0.021, acc.: 100.00%), generator(loss: 5.010)
# Epoch: 105, discriminator(loss: 0.022, acc.: 100.00%), generator(loss: 5.497)
# Epoch: 106, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 5.280)
# Epoch: 107, discriminator(loss: 0.020, acc.: 100.00%), generator(loss: 5.265)
# Epoch: 108, discriminator(loss: 0.023, acc.: 100.00%), generator(loss: 5.246)
# Epoch: 109, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 5.371)
# Epoch: 110, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 5.286)
# Epoch: 111, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 5.438)
# Epoch: 112, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 5.484)
# Epoch: 113, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 5.175)
# Epoch: 114, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 5.430)
# Epoch: 115, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 5.517)
# Epoch: 116, discriminator(loss: 0.020, acc.: 100.00%), generator(loss: 5.687)
# Epoch: 117, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 5.500)
# Epoch: 118, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 5.571)
# Epoch: 119, discriminator(loss: 0.016, acc.: 100.00%), generator(loss: 5.614)
# Epoch: 120, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 5.487)
# Epoch: 121, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 5.564)
# Epoch: 122, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 5.524)
# Epoch: 123, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 5.850)
# Epoch: 124, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 5.897)
# Epoch: 125, discriminator(loss: 0.016, acc.: 100.00%), generator(loss: 5.655)
# Epoch: 126, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 5.824)
# Epoch: 127, discriminator(loss: 0.026, acc.: 100.00%), generator(loss: 5.943)
# Epoch: 128, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 6.002)
# Epoch: 129, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 5.814)
# Epoch: 130, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 6.115)
# Epoch: 131, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 6.328)
# Epoch: 132, discriminator(loss: 0.012, acc.: 100.00%), generator(loss: 6.054)
# Epoch: 133, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 6.048)
# Epoch: 134, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 6.120)
# Epoch: 135, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 6.066)
# Epoch: 136, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 5.968)
# Epoch: 137, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 6.295)
# Epoch: 138, discriminator(loss: 0.030, acc.: 100.00%), generator(loss: 5.853)
# Epoch: 139, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 6.275)
# Epoch: 140, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 6.341)
# Epoch: 141, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 6.607)
# Epoch: 142, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 6.470)
# Epoch: 143, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 6.902)
# Epoch: 144, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 6.967)
# Epoch: 145, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 6.622)
# Epoch: 146, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 6.925)
# Epoch: 147, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 6.935)
# Epoch: 148, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 6.692)
# Epoch: 149, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 6.770)
# Epoch: 150, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 6.784)
# Epoch: 151, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 6.852)
# Epoch: 152, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 6.630)
# Epoch: 153, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 6.539)
# Epoch: 154, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 6.935)
# Epoch: 155, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 6.684)
# Epoch: 156, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 7.001)
# Epoch: 157, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 7.308)
# Epoch: 158, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 7.287)
# Epoch: 159, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 6.329)
# Epoch: 160, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 6.943)
# Epoch: 161, discriminator(loss: 0.012, acc.: 100.00%), generator(loss: 7.151)
# Epoch: 162, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 7.531)
# Epoch: 163, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 7.549)
# Epoch: 164, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 7.419)
# Epoch: 165, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 7.426)
# Epoch: 166, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 7.252)
# Epoch: 167, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 7.230)
# Epoch: 168, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 6.907)
# Epoch: 169, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 7.018)
# Epoch: 170, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 7.135)
# Epoch: 171, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 7.071)
# Epoch: 172, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 7.334)
# Epoch: 173, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 7.335)
# Epoch: 174, discriminator(loss: 0.012, acc.: 100.00%), generator(loss: 7.344)
# Epoch: 175, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 7.679)
# Epoch: 176, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 7.431)
# Epoch: 177, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 7.288)
# Epoch: 178, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 7.248)
# Epoch: 179, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 7.294)
# Epoch: 180, discriminator(loss: 0.009, acc.: 100.00%), generator(loss: 7.188)
# Epoch: 181, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 7.081)
# Epoch: 182, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 7.778)
# Epoch: 183, discriminator(loss: 0.031, acc.: 100.00%), generator(loss: 6.734)
# Epoch: 184, discriminator(loss: 0.018, acc.: 100.00%), generator(loss: 7.470)
# Epoch: 185, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 8.391)
# Epoch: 186, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 8.099)
# Epoch: 187, discriminator(loss: 0.022, acc.: 100.00%), generator(loss: 7.248)
# Epoch: 188, discriminator(loss: 0.026, acc.: 100.00%), generator(loss: 7.647)
# Epoch: 189, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 8.512)
# Epoch: 190, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 8.649)
# Epoch: 191, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 7.742)
# Epoch: 192, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 7.912)
# Epoch: 193, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 7.962)
# Epoch: 194, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 7.768)
# Epoch: 195, discriminator(loss: 0.015, acc.: 100.00%), generator(loss: 8.227)
# Epoch: 196, discriminator(loss: 0.017, acc.: 100.00%), generator(loss: 7.038)
# Epoch: 197, discriminator(loss: 0.045, acc.: 99.22%), generator(loss: 8.082)
# Epoch: 198, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 9.033)
# Epoch: 199, discriminator(loss: 0.300, acc.: 85.94%), generator(loss: 7.113)
# Epoch: 200, discriminator(loss: 0.239, acc.: 90.62%), generator(loss: 11.057)
# Epoch: 201, discriminator(loss: 0.041, acc.: 97.66%), generator(loss: 14.407)
# Epoch: 202, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 13.871)
# Epoch: 203, discriminator(loss: 0.115, acc.: 96.88%), generator(loss: 9.018)
# Epoch: 204, discriminator(loss: 0.136, acc.: 93.75%), generator(loss: 8.519)
# Epoch: 205, discriminator(loss: 0.041, acc.: 98.44%), generator(loss: 9.690)
# Epoch: 206, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 10.232)
# Epoch: 207, discriminator(loss: 0.011, acc.: 100.00%), generator(loss: 8.882)
# Epoch: 208, discriminator(loss: 0.013, acc.: 100.00%), generator(loss: 8.851)
# Epoch: 209, discriminator(loss: 0.069, acc.: 97.66%), generator(loss: 6.463)
# Epoch: 210, discriminator(loss: 0.136, acc.: 93.75%), generator(loss: 8.103)
# Epoch: 211, discriminator(loss: 0.035, acc.: 97.66%), generator(loss: 8.258)
# Epoch: 212, discriminator(loss: 0.052, acc.: 97.66%), generator(loss: 7.869)
# Epoch: 213, discriminator(loss: 0.045, acc.: 99.22%), generator(loss: 8.399)
# Epoch: 214, discriminator(loss: 0.137, acc.: 95.31%), generator(loss: 7.131)
# Epoch: 215, discriminator(loss: 0.028, acc.: 100.00%), generator(loss: 8.169)
# Epoch: 216, discriminator(loss: 0.129, acc.: 95.31%), generator(loss: 6.783)
# Epoch: 217, discriminator(loss: 0.059, acc.: 96.09%), generator(loss: 7.950)
# Epoch: 218, discriminator(loss: 0.025, acc.: 99.22%), generator(loss: 8.207)
# Epoch: 219, discriminator(loss: 1.238, acc.: 64.84%), generator(loss: 3.185)
# Epoch: 220, discriminator(loss: 0.715, acc.: 75.00%), generator(loss: 7.571)
# Epoch: 221, discriminator(loss: 0.037, acc.: 98.44%), generator(loss: 10.982)
# Epoch: 222, discriminator(loss: 0.026, acc.: 99.22%), generator(loss: 10.448)
# Epoch: 223, discriminator(loss: 0.033, acc.: 98.44%), generator(loss: 9.452)
# Epoch: 224, discriminator(loss: 0.019, acc.: 100.00%), generator(loss: 8.082)
# Epoch: 225, discriminator(loss: 0.088, acc.: 96.88%), generator(loss: 6.665)
# Epoch: 226, discriminator(loss: 0.070, acc.: 98.44%), generator(loss: 6.937)
# Epoch: 227, discriminator(loss: 0.285, acc.: 85.94%), generator(loss: 6.103)
# Epoch: 228, discriminator(loss: 0.051, acc.: 100.00%), generator(loss: 7.424)
# Epoch: 229, discriminator(loss: 0.043, acc.: 99.22%), generator(loss: 6.642)
# Epoch: 230, discriminator(loss: 0.202, acc.: 89.84%), generator(loss: 6.043)
# Epoch: 231, discriminator(loss: 0.029, acc.: 100.00%), generator(loss: 6.641)
# Epoch: 232, discriminator(loss: 0.417, acc.: 79.69%), generator(loss: 5.298)
# Epoch: 233, discriminator(loss: 0.118, acc.: 96.09%), generator(loss: 7.531)
# Epoch: 234, discriminator(loss: 0.065, acc.: 97.66%), generator(loss: 7.064)
# Epoch: 235, discriminator(loss: 0.139, acc.: 93.75%), generator(loss: 6.216)
# Epoch: 236, discriminator(loss: 0.057, acc.: 97.66%), generator(loss: 7.003)
# Epoch: 237, discriminator(loss: 0.235, acc.: 88.28%), generator(loss: 5.675)
# Epoch: 238, discriminator(loss: 0.068, acc.: 98.44%), generator(loss: 7.081)
# Epoch: 239, discriminator(loss: 0.539, acc.: 74.22%), generator(loss: 4.241)
# Epoch: 240, discriminator(loss: 0.150, acc.: 94.53%), generator(loss: 6.920)
# Epoch: 241, discriminator(loss: 0.025, acc.: 100.00%), generator(loss: 8.007)
# Epoch: 242, discriminator(loss: 0.531, acc.: 74.22%), generator(loss: 4.398)
# Epoch: 243, discriminator(loss: 0.134, acc.: 94.53%), generator(loss: 6.192)
# Epoch: 244, discriminator(loss: 0.024, acc.: 100.00%), generator(loss: 7.352)
# Epoch: 245, discriminator(loss: 0.060, acc.: 100.00%), generator(loss: 6.515)
# Epoch: 246, discriminator(loss: 0.074, acc.: 96.09%), generator(loss: 5.910)
# Epoch: 247, discriminator(loss: 0.109, acc.: 96.88%), generator(loss: 6.652)
# Epoch: 248, discriminator(loss: 0.812, acc.: 61.72%), generator(loss: 3.012)
# Epoch: 249, discriminator(loss: 0.249, acc.: 87.50%), generator(loss: 5.900)
# Epoch: 250, discriminator(loss: 0.017, acc.: 100.00%), generator(loss: 7.610)
# Epoch: 251, discriminator(loss: 0.831, acc.: 61.72%), generator(loss: 2.766)
# Epoch: 252, discriminator(loss: 0.358, acc.: 78.12%), generator(loss: 4.957)
# Epoch: 253, discriminator(loss: 0.028, acc.: 100.00%), generator(loss: 7.230)
# Epoch: 254, discriminator(loss: 0.048, acc.: 100.00%), generator(loss: 6.364)
# Epoch: 255, discriminator(loss: 0.030, acc.: 100.00%), generator(loss: 5.698)
# Epoch: 256, discriminator(loss: 0.088, acc.: 97.66%), generator(loss: 5.004)
# Epoch: 257, discriminator(loss: 0.096, acc.: 97.66%), generator(loss: 4.771)
# Epoch: 258, discriminator(loss: 0.055, acc.: 100.00%), generator(loss: 5.232)
# Epoch: 259, discriminator(loss: 0.218, acc.: 89.84%), generator(loss: 4.250)
# Epoch: 260, discriminator(loss: 0.096, acc.: 96.88%), generator(loss: 5.984)
# Epoch: 261, discriminator(loss: 2.287, acc.: 33.59%), generator(loss: 0.570)
# Epoch: 262, discriminator(loss: 1.500, acc.: 50.78%), generator(loss: 2.175)
# Epoch: 263, discriminator(loss: 0.181, acc.: 91.41%), generator(loss: 4.941)
# Epoch: 264, discriminator(loss: 0.046, acc.: 98.44%), generator(loss: 6.120)
# Epoch: 265, discriminator(loss: 0.188, acc.: 92.97%), generator(loss: 3.704)
# Epoch: 266, discriminator(loss: 0.162, acc.: 89.84%), generator(loss: 4.188)
# Epoch: 267, discriminator(loss: 0.090, acc.: 98.44%), generator(loss: 4.812)
# Epoch: 268, discriminator(loss: 0.113, acc.: 98.44%), generator(loss: 3.761)
# Epoch: 269, discriminator(loss: 0.088, acc.: 99.22%), generator(loss: 4.022)
# Epoch: 270, discriminator(loss: 0.134, acc.: 96.09%), generator(loss: 3.824)
# Epoch: 271, discriminator(loss: 0.127, acc.: 99.22%), generator(loss: 4.113)
# Epoch: 272, discriminator(loss: 0.111, acc.: 97.66%), generator(loss: 3.969)
# Epoch: 273, discriminator(loss: 0.251, acc.: 92.19%), generator(loss: 3.221)
# Epoch: 274, discriminator(loss: 0.151, acc.: 95.31%), generator(loss: 4.766)
# Epoch: 275, discriminator(loss: 0.770, acc.: 56.25%), generator(loss: 1.732)
# Epoch: 276, discriminator(loss: 0.243, acc.: 87.50%), generator(loss: 4.003)
# Epoch: 277, discriminator(loss: 0.076, acc.: 99.22%), generator(loss: 4.937)
# Epoch: 278, discriminator(loss: 0.402, acc.: 80.47%), generator(loss: 2.542)
# Epoch: 279, discriminator(loss: 0.192, acc.: 89.06%), generator(loss: 4.215)
# Epoch: 280, discriminator(loss: 0.039, acc.: 100.00%), generator(loss: 4.850)
# Epoch: 281, discriminator(loss: 0.529, acc.: 74.22%), generator(loss: 1.959)
# Epoch: 282, discriminator(loss: 0.205, acc.: 92.19%), generator(loss: 4.061)
# Epoch: 283, discriminator(loss: 0.054, acc.: 100.00%), generator(loss: 4.784)
# Epoch: 284, discriminator(loss: 0.757, acc.: 57.03%), generator(loss: 1.917)
# Epoch: 285, discriminator(loss: 0.270, acc.: 82.81%), generator(loss: 3.826)
# Epoch: 286, discriminator(loss: 0.059, acc.: 99.22%), generator(loss: 5.058)
# Epoch: 287, discriminator(loss: 0.368, acc.: 82.03%), generator(loss: 2.338)
# Epoch: 288, discriminator(loss: 0.180, acc.: 92.19%), generator(loss: 4.175)
# Epoch: 289, discriminator(loss: 0.083, acc.: 99.22%), generator(loss: 4.366)
# Epoch: 290, discriminator(loss: 0.894, acc.: 48.44%), generator(loss: 1.836)
# Epoch: 291, discriminator(loss: 0.183, acc.: 92.97%), generator(loss: 3.741)
# Epoch: 292, discriminator(loss: 0.060, acc.: 99.22%), generator(loss: 4.684)
# Epoch: 293, discriminator(loss: 0.676, acc.: 63.28%), generator(loss: 1.661)
# Epoch: 294, discriminator(loss: 0.322, acc.: 78.91%), generator(loss: 3.974)
# Epoch: 295, discriminator(loss: 0.060, acc.: 100.00%), generator(loss: 4.812)
# Epoch: 296, discriminator(loss: 0.855, acc.: 53.12%), generator(loss: 1.388)
# Epoch: 297, discriminator(loss: 0.415, acc.: 74.22%), generator(loss: 3.050)
# Epoch: 298, discriminator(loss: 0.057, acc.: 99.22%), generator(loss: 4.737)
# Epoch: 299, discriminator(loss: 0.743, acc.: 55.47%), generator(loss: 1.506)
# Epoch: 300, discriminator(loss: 0.369, acc.: 75.00%), generator(loss: 3.287)
# Epoch: 301, discriminator(loss: 0.062, acc.: 99.22%), generator(loss: 4.869)
# Epoch: 302, discriminator(loss: 0.465, acc.: 77.34%), generator(loss: 1.680)
# Epoch: 303, discriminator(loss: 0.304, acc.: 82.03%), generator(loss: 3.054)
# Epoch: 304, discriminator(loss: 0.080, acc.: 100.00%), generator(loss: 4.262)
# Epoch: 305, discriminator(loss: 0.416, acc.: 80.47%), generator(loss: 1.882)
# Epoch: 306, discriminator(loss: 0.249, acc.: 86.72%), generator(loss: 3.357)
# Epoch: 307, discriminator(loss: 0.127, acc.: 98.44%), generator(loss: 3.658)
# Epoch: 308, discriminator(loss: 0.417, acc.: 77.34%), generator(loss: 2.294)
# Epoch: 309, discriminator(loss: 0.142, acc.: 97.66%), generator(loss: 3.857)
# Epoch: 310, discriminator(loss: 0.431, acc.: 79.69%), generator(loss: 2.607)
# Epoch: 311, discriminator(loss: 0.120, acc.: 99.22%), generator(loss: 3.718)
# Epoch: 312, discriminator(loss: 0.410, acc.: 84.38%), generator(loss: 2.089)
# Epoch: 313, discriminator(loss: 0.196, acc.: 90.62%), generator(loss: 3.908)
# Epoch: 314, discriminator(loss: 0.975, acc.: 46.09%), generator(loss: 1.263)
# Epoch: 315, discriminator(loss: 0.351, acc.: 79.69%), generator(loss: 2.808)
# Epoch: 316, discriminator(loss: 0.112, acc.: 99.22%), generator(loss: 4.160)
# Epoch: 317, discriminator(loss: 1.282, acc.: 33.59%), generator(loss: 0.448)
# Epoch: 318, discriminator(loss: 0.702, acc.: 57.03%), generator(loss: 1.643)
# Epoch: 319, discriminator(loss: 0.132, acc.: 96.09%), generator(loss: 3.741)
# Epoch: 320, discriminator(loss: 0.253, acc.: 95.31%), generator(loss: 2.445)
# Epoch: 321, discriminator(loss: 0.176, acc.: 93.75%), generator(loss: 2.867)
# Epoch: 322, discriminator(loss: 0.322, acc.: 88.28%), generator(loss: 2.568)
# Epoch: 323, discriminator(loss: 0.210, acc.: 91.41%), generator(loss: 2.881)
# Epoch: 324, discriminator(loss: 0.247, acc.: 94.53%), generator(loss: 2.726)
# Epoch: 325, discriminator(loss: 0.221, acc.: 96.09%), generator(loss: 2.950)
# Epoch: 326, discriminator(loss: 0.386, acc.: 81.25%), generator(loss: 2.420)
# Epoch: 327, discriminator(loss: 0.215, acc.: 92.97%), generator(loss: 2.955)
# Epoch: 328, discriminator(loss: 0.635, acc.: 61.72%), generator(loss: 1.631)
# Epoch: 329, discriminator(loss: 0.189, acc.: 95.31%), generator(loss: 3.568)
# Epoch: 330, discriminator(loss: 1.016, acc.: 39.84%), generator(loss: 0.680)
# Epoch: 331, discriminator(loss: 0.529, acc.: 64.06%), generator(loss: 2.280)
# Epoch: 332, discriminator(loss: 0.142, acc.: 99.22%), generator(loss: 3.372)
# Epoch: 333, discriminator(loss: 0.840, acc.: 47.66%), generator(loss: 0.937)
# Epoch: 334, discriminator(loss: 0.381, acc.: 75.00%), generator(loss: 2.059)
# Epoch: 335, discriminator(loss: 0.125, acc.: 99.22%), generator(loss: 3.237)
# Epoch: 336, discriminator(loss: 0.621, acc.: 64.06%), generator(loss: 1.565)
# Epoch: 337, discriminator(loss: 0.219, acc.: 91.41%), generator(loss: 2.750)
# Epoch: 338, discriminator(loss: 0.333, acc.: 89.84%), generator(loss: 2.105)
# Epoch: 339, discriminator(loss: 0.213, acc.: 95.31%), generator(loss: 2.956)
# Epoch: 340, discriminator(loss: 0.374, acc.: 86.72%), generator(loss: 2.281)
# Epoch: 341, discriminator(loss: 0.174, acc.: 98.44%), generator(loss: 3.081)
# Epoch: 342, discriminator(loss: 0.489, acc.: 73.44%), generator(loss: 1.626)
# Epoch: 343, discriminator(loss: 0.232, acc.: 95.31%), generator(loss: 2.860)
# Epoch: 344, discriminator(loss: 0.627, acc.: 60.16%), generator(loss: 1.682)
# Epoch: 345, discriminator(loss: 0.201, acc.: 94.53%), generator(loss: 2.933)
# Epoch: 346, discriminator(loss: 0.716, acc.: 50.00%), generator(loss: 1.234)
# Epoch: 347, discriminator(loss: 0.283, acc.: 84.38%), generator(loss: 2.669)
# Epoch: 348, discriminator(loss: 0.256, acc.: 96.09%), generator(loss: 2.495)
# Epoch: 349, discriminator(loss: 0.311, acc.: 85.94%), generator(loss: 2.169)
# Epoch: 350, discriminator(loss: 0.273, acc.: 92.97%), generator(loss: 2.650)
# Epoch: 351, discriminator(loss: 0.395, acc.: 84.38%), generator(loss: 2.137)
# Epoch: 352, discriminator(loss: 0.220, acc.: 96.09%), generator(loss: 2.715)
# Epoch: 353, discriminator(loss: 0.794, acc.: 49.22%), generator(loss: 1.130)
# Epoch: 354, discriminator(loss: 0.281, acc.: 87.50%), generator(loss: 3.024)
# Epoch: 355, discriminator(loss: 0.980, acc.: 41.41%), generator(loss: 0.818)
# Epoch: 356, discriminator(loss: 0.372, acc.: 75.78%), generator(loss: 2.269)
# Epoch: 357, discriminator(loss: 0.240, acc.: 97.66%), generator(loss: 2.445)
# Epoch: 358, discriminator(loss: 0.382, acc.: 87.50%), generator(loss: 1.776)
# Epoch: 359, discriminator(loss: 0.249, acc.: 90.62%), generator(loss: 2.728)
# Epoch: 360, discriminator(loss: 0.547, acc.: 67.19%), generator(loss: 1.331)
# Epoch: 361, discriminator(loss: 0.264, acc.: 87.50%), generator(loss: 2.957)
# Epoch: 362, discriminator(loss: 0.376, acc.: 92.19%), generator(loss: 2.074)
# Epoch: 363, discriminator(loss: 0.271, acc.: 90.62%), generator(loss: 2.507)
# Epoch: 364, discriminator(loss: 0.533, acc.: 68.75%), generator(loss: 1.866)
# Epoch: 365, discriminator(loss: 0.202, acc.: 96.09%), generator(loss: 3.227)
# Epoch: 366, discriminator(loss: 0.936, acc.: 38.28%), generator(loss: 0.728)
# Epoch: 367, discriminator(loss: 0.396, acc.: 68.75%), generator(loss: 2.184)
# Epoch: 368, discriminator(loss: 0.349, acc.: 89.84%), generator(loss: 2.233)
# Epoch: 369, discriminator(loss: 0.263, acc.: 93.75%), generator(loss: 2.191)
# Epoch: 370, discriminator(loss: 0.317, acc.: 90.62%), generator(loss: 2.165)
# Epoch: 371, discriminator(loss: 0.335, acc.: 89.06%), generator(loss: 2.514)
# Epoch: 372, discriminator(loss: 0.392, acc.: 84.38%), generator(loss: 1.722)
# Epoch: 7841, discriminator(loss: 0.700, acc.: 59.38%), generator(loss: 1.054)
# Epoch: 7842, discriminator(loss: 0.617, acc.: 67.19%), generator(loss: 1.132)
# Epoch: 7843, discriminator(loss: 0.553, acc.: 68.75%), generator(loss: 1.055)
# Epoch: 7844, discriminator(loss: 0.660, acc.: 64.06%), generator(loss: 1.090)
# Epoch: 7845, discriminator(loss: 0.609, acc.: 64.06%), generator(loss: 1.235)
# Epoch: 7846, discriminator(loss: 0.563, acc.: 71.09%), generator(loss: 1.199)
# Epoch: 7847, discriminator(loss: 0.644, acc.: 63.28%), generator(loss: 1.081)
# Epoch: 7848, discriminator(loss: 0.694, acc.: 59.38%), generator(loss: 1.314)
# Epoch: 7849, discriminator(loss: 0.589, acc.: 70.31%), generator(loss: 1.240)
# Epoch: 7850, discriminator(loss: 0.629, acc.: 64.06%), generator(loss: 1.201)
# Epoch: 7851, discriminator(loss: 0.661, acc.: 65.62%), generator(loss: 1.276)
# Epoch: 7852, discriminator(loss: 0.641, acc.: 65.62%), generator(loss: 1.164)
# Epoch: 7853, discriminator(loss: 0.613, acc.: 67.19%), generator(loss: 1.115)
# Epoch: 7854, discriminator(loss: 0.627, acc.: 68.75%), generator(loss: 1.260)
# Epoch: 7855, discriminator(loss: 0.585, acc.: 70.31%), generator(loss: 1.164)
# Epoch: 7856, discriminator(loss: 0.604, acc.: 64.06%), generator(loss: 1.111)
# Epoch: 7857, discriminator(loss: 0.636, acc.: 61.72%), generator(loss: 1.091)
# Epoch: 7858, discriminator(loss: 0.605, acc.: 65.62%), generator(loss: 1.082)
# Epoch: 7859, discriminator(loss: 0.662, acc.: 59.38%), generator(loss: 1.114)
# Epoch: 7860, discriminator(loss: 0.583, acc.: 69.53%), generator(loss: 1.146)
# Epoch: 7861, discriminator(loss: 0.617, acc.: 71.88%), generator(loss: 1.227)
# Epoch: 7862, discriminator(loss: 0.632, acc.: 67.97%), generator(loss: 1.240)
# Epoch: 7863, discriminator(loss: 0.641, acc.: 66.41%), generator(loss: 1.156)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\api\_v1\keras\layers\__init__.py in <module>
#      54     imgs_fake = generator.predict(noise)
#      55
# ---> 56     dis_loss_real = discriminator.train_on_batch(imgs_real, np.ones((batch_size,1)))
#      57     dis_loss_fake = discriminator.train_on_batch(imgs_fake, np.zeros((batch_size,1)))
#      58     dis_loss = np.add(dis_loss_real,dis_loss_fake)*0.5
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3275         tensor_type = dtypes_module.as_dtype(tensor.dtype)
#    3276         array_vals.append(np.asarray(value,
# -> 3277                                      dtype=tensor_type.as_numpy_dtype))
#    3278
#    3279     if self.feed_dict:
#
# ~\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# KeyboardInterrupt:

# %%
noise = Input(shape=(100,))

# %%
noise
# Out:
# <tf.Tensor 'input_4:0' shape=(?, 100) dtype=float32>

# %%
noise = np.random.randn(batch_size, 3)

# %%
noise
# Out:
# array([[-0.9321557 ,  0.03652149,  0.37006694],
#        [-0.1219026 , -0.82375714, -0.11419537],
#        [-0.34974768, -0.32972548, -0.06249169],
#        [ 0.96286218,  0.45486861,  1.44371126],
#        [ 1.68506157,  0.88150375,  1.11846293],
#        [-0.94547262,  1.51844409, -2.96334228],
#        [-0.30647736, -0.75209161, -1.03700286],
#        [-1.95252808,  0.11748862, -0.71964998],
#        [ 1.03677342, -0.10826139,  0.49525957],
#        [ 1.32809853,  0.95517275, -0.21235903],
#        [ 0.57485859,  0.39829954, -0.91823343],
#        [-0.45287831,  1.00330871, -0.45304861],
#        [-0.43450243, -3.56446464,  0.40511714],
#        [-0.93879788, -0.663396  , -0.7040008 ],
#        [-0.18244128,  0.94404118, -0.09467352],
#        [-1.54481632, -0.40086145, -0.67356362],
#        [-0.52772941, -0.14977711,  0.56052728],
#        [-1.39964081, -2.29162937,  0.20800592],
#        [-0.68790133, -0.0228689 , -0.84205574],
#        [ 0.58099386,  0.07363217,  0.28110249],
#        [-0.3306379 , -0.34719621, -0.22238933],
#        [ 0.34226643,  0.76940412, -0.50440237],
#        [-0.59050906,  1.48452139, -0.3244111 ],
#        [ 1.23384438,  1.63984663, -0.73348455],
#        [-0.74857767, -0.19280621, -1.1131748 ],
#        [-0.352985  ,  0.50974422, -0.327971  ],
#        [ 0.18736864,  1.73879615, -0.69034518],
#        [-0.84109871, -0.44430363,  0.59226547],
#        [ 0.05861048, -0.53470096, -2.13662892],
#        [ 1.69647715, -1.27711675, -0.86441629],
#        [-0.529795  , -0.45771876, -1.92934052],
#        [ 0.26055247, -0.36715006, -0.80304009],
#        [-0.43274252,  1.29607   ,  0.7851715 ],
#        [-0.47897762,  1.04119706,  2.00202295],
#        [-0.23244761,  0.22356624, -1.00028455],
#        [-1.17901381, -0.21263164, -0.49136361],
#        [ 0.04563602,  0.75983273, -0.51413381],
#        [-0.10130697,  0.64831097, -0.91704572],
#        [-0.02495999, -0.63224005, -1.40968467],
#        [ 1.50671996, -0.09054576, -0.01329382],
#        [ 1.59155502,  0.29730952,  3.1506439 ],
#        [ 1.17520954,  0.0136568 ,  1.15043138],
#        [ 0.20789041,  0.595215  ,  0.13929624],
#        [ 0.62365586,  0.22793686, -2.73939848],
#        [ 0.15896378, -0.52118057, -2.00190279],
#        [ 2.34970369, -0.68834614, -0.54910452],
#        [-0.34062119, -0.52397535,  1.10866301],
#        [ 0.12403853, -1.51312504,  0.79791971],
#        [-1.42747052, -0.83202413,  0.16684422],
#        [ 1.78422937, -0.60168889,  1.22179324],
#        [-2.46084774, -1.14974763, -0.65094398],
#        [-2.06530892,  0.67702173, -0.58700126],
#        [-0.28361428,  0.06758907, -0.0363787 ],
#        [ 1.11758872,  0.42561562, -0.52046302],
#        [-0.02425814,  0.66048518,  0.46169586],
#        [-0.40139928, -0.51577471,  0.63238582],
#        [-1.11979448, -0.09349523, -0.50984813],
#        [-0.05377017, -0.87255127, -0.17884213],
#        [-0.96014685, -1.55817216,  0.4513807 ],
#        [ 1.69209185,  1.46957337, -2.78864503],
#        [-0.09310697,  0.35353578, -0.44782557],
#        [-0.35429428, -0.39963637, -0.73437541],
#        [-0.50706155,  1.28490125, -0.16348341],
#        [-0.29652173,  1.48635328,  0.22350666]])

# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.load('C:/Users/user/Desktop/研究所/程式/ML/font_data.npy')
x_train = x_train/127.5-1.

latent_size = 128
img_shape = (48,48)

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

discriminator = Sequential()
discriminator.add(Reshape(img_shape+(1,), input_shape=img_shape))
discriminator.add(Conv2D(64, kernel_size=5, strides=2, padding='same'))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding='same'))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy',
                      optimizer=Adam(0.0002, 0.5),
                      metrics=['accuracy'])

generator = Sequential()
generator.add(Dense(12*12*256, input_dim=latent_size))
generator.add(BatchNormalization())
generator.add(LeakyReLU())
generator.add(Reshape((12,12,256)))
generator.add(Conv2DTranspose(128, kernel_size=5, strides=1, padding='same'))
generator.add(BatchNormalization())
generator.add(LeakyReLU())
generator.add(Conv2DTranspose(64, kernel_size=5, strides=2, padding='same'))
generator.add(BatchNormalization())
generator.add(LeakyReLU())
generator.add(Conv2DTranspose(1, kernel_size=5, strides=2, padding='same', activation='tanh'))
generator.add(Reshape(img_shape))

noise = Input(shape=(latent_size,))
img = generator(noise)
discriminator.trainable = False
validity = discriminator(img)
combined = Model(noise, validity)
combined.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

noise_test = np.random.randn(100, latent_size)
batch_size = 64
for epoch in range(10001):
    
    imgs_real = x_train[np.random.randint(0, len(x_train), batch_size)]
    
    noise = np.random.randn(batch_size, latent_size)
    imgs_fake = generator.predict(noise)

    dis_loss_real = discriminator.train_on_batch(imgs_real, np.ones((batch_size,1)))
    dis_loss_fake = discriminator.train_on_batch(imgs_fake, np.zeros((batch_size,1)))
    dis_loss = np.add(dis_loss_real,dis_loss_fake)*0.5

    noise = np.random.randn(batch_size, latent_size)
    gen_loss = combined.train_on_batch(noise, np.ones((batch_size,1)))
                                       
    print("Epoch: %d, discriminator(loss: %.3f, acc.: %.2f%%), generator(loss: %.3f)" %
          (epoch, dis_loss[0], dis_loss[1]*100., gen_loss))

    if epoch % 100 == 0:
        imgs_fake = generator.predict(noise_test)
                                       
        fig = plt.figure(figsize=(10,10), dpi=80)
        plt.subplots_adjust(0.05,0.05,0.95,0.95,0.1,0.1)
        for i in range(100):
            plt.subplot(10,10,i+1)
            plt.axis('off')
            plt.imshow(imgs_fake[i], cmap='Greys')
        fig.suptitle('epoch: %05d' % epoch, color='Blue', fontsize=16)
        fig.savefig("%05d.jpg" % epoch)
        plt.close()
# Out:
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Epoch: 0, discriminator(loss: 0.680, acc.: 30.47%), generator(loss: 0.648)
# Epoch: 1, discriminator(loss: 0.574, acc.: 50.00%), generator(loss: 0.563)
# Epoch: 2, discriminator(loss: 0.506, acc.: 50.00%), generator(loss: 0.463)
# Epoch: 3, discriminator(loss: 0.452, acc.: 50.00%), generator(loss: 0.363)
# Epoch: 4, discriminator(loss: 0.412, acc.: 50.00%), generator(loss: 0.276)
# Epoch: 5, discriminator(loss: 0.388, acc.: 50.00%), generator(loss: 0.211)
# Epoch: 6, discriminator(loss: 0.371, acc.: 58.59%), generator(loss: 0.163)
# Epoch: 7, discriminator(loss: 0.358, acc.: 100.00%), generator(loss: 0.131)
# Epoch: 8, discriminator(loss: 0.350, acc.: 100.00%), generator(loss: 0.108)
# Epoch: 9, discriminator(loss: 0.344, acc.: 100.00%), generator(loss: 0.089)
# Epoch: 10, discriminator(loss: 0.343, acc.: 100.00%), generator(loss: 0.078)
# Epoch: 11, discriminator(loss: 0.345, acc.: 98.44%), generator(loss: 0.076)
# Epoch: 12, discriminator(loss: 0.350, acc.: 71.88%), generator(loss: 0.077)
# Epoch: 13, discriminator(loss: 0.361, acc.: 52.34%), generator(loss: 0.086)
# Epoch: 14, discriminator(loss: 0.373, acc.: 50.00%), generator(loss: 0.097)
# Epoch: 15, discriminator(loss: 0.383, acc.: 50.00%), generator(loss: 0.114)
# Epoch: 16, discriminator(loss: 0.386, acc.: 50.00%), generator(loss: 0.130)
# Epoch: 17, discriminator(loss: 0.386, acc.: 50.00%), generator(loss: 0.138)
# Epoch: 18, discriminator(loss: 0.377, acc.: 50.00%), generator(loss: 0.147)
# Epoch: 19, discriminator(loss: 0.365, acc.: 96.09%), generator(loss: 0.141)
# Epoch: 20, discriminator(loss: 0.342, acc.: 100.00%), generator(loss: 0.130)
# Epoch: 21, discriminator(loss: 0.317, acc.: 100.00%), generator(loss: 0.124)
# Epoch: 22, discriminator(loss: 0.291, acc.: 100.00%), generator(loss: 0.124)
# Epoch: 23, discriminator(loss: 0.261, acc.: 100.00%), generator(loss: 0.137)
# Epoch: 24, discriminator(loss: 0.235, acc.: 100.00%), generator(loss: 0.161)
# Epoch: 25, discriminator(loss: 0.210, acc.: 100.00%), generator(loss: 0.164)
# Epoch: 26, discriminator(loss: 0.189, acc.: 100.00%), generator(loss: 0.150)
# Epoch: 27, discriminator(loss: 0.168, acc.: 100.00%), generator(loss: 0.140)
# Epoch: 28, discriminator(loss: 0.148, acc.: 100.00%), generator(loss: 0.130)
# Epoch: 29, discriminator(loss: 0.127, acc.: 100.00%), generator(loss: 0.106)
# Epoch: 30, discriminator(loss: 0.103, acc.: 100.00%), generator(loss: 0.070)
# Epoch: 31, discriminator(loss: 0.081, acc.: 100.00%), generator(loss: 0.040)
# Epoch: 32, discriminator(loss: 0.061, acc.: 100.00%), generator(loss: 0.015)
# Epoch: 33, discriminator(loss: 0.040, acc.: 100.00%), generator(loss: 0.007)
# Epoch: 34, discriminator(loss: 0.031, acc.: 100.00%), generator(loss: 0.008)
# Epoch: 35, discriminator(loss: 0.020, acc.: 100.00%), generator(loss: 0.011)
# Epoch: 36, discriminator(loss: 0.014, acc.: 100.00%), generator(loss: 0.003)
# Epoch: 37, discriminator(loss: 0.012, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 38, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 39, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 40, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 41, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.004)
# Epoch: 42, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 43, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 44, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 45, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 46, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 47, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 48, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 49, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 50, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 51, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 52, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 53, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 54, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 55, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 56, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 57, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.003)
# Epoch: 58, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 59, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 60, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 61, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 62, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 63, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 64, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.002)
# Epoch: 65, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 66, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 67, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 68, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 69, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 70, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 71, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 72, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 73, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 74, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 75, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 76, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 77, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 78, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 79, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 80, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 81, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 82, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 83, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 84, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 85, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 86, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 87, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 88, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 89, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 90, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 91, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 92, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 93, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 94, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 95, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 96, discriminator(loss: 0.021, acc.: 100.00%), generator(loss: 0.030)
# Epoch: 97, discriminator(loss: 0.131, acc.: 95.31%), generator(loss: 0.000)
# Epoch: 98, discriminator(loss: 0.891, acc.: 50.00%), generator(loss: 1.999)
# Epoch: 99, discriminator(loss: 0.445, acc.: 85.16%), generator(loss: 2.103)
# Epoch: 100, discriminator(loss: 0.821, acc.: 89.06%), generator(loss: 0.001)
# Epoch: 101, discriminator(loss: 0.312, acc.: 92.97%), generator(loss: 0.000)
# Epoch: 102, discriminator(loss: 0.066, acc.: 98.44%), generator(loss: 0.000)
# Epoch: 103, discriminator(loss: 0.068, acc.: 96.88%), generator(loss: 0.000)
# Epoch: 104, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 105, discriminator(loss: 0.044, acc.: 98.44%), generator(loss: 0.000)
# Epoch: 106, discriminator(loss: 0.068, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 107, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 108, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 109, discriminator(loss: 0.058, acc.: 98.44%), generator(loss: 0.000)
# Epoch: 110, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 111, discriminator(loss: 0.045, acc.: 98.44%), generator(loss: 0.000)
# Epoch: 112, discriminator(loss: 0.067, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 113, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 114, discriminator(loss: 0.025, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 115, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 116, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 117, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 118, discriminator(loss: 0.011, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 119, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 120, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 121, discriminator(loss: 0.011, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 122, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 123, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 124, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 125, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 126, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 127, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 128, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 129, discriminator(loss: 0.030, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 130, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 131, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 132, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 133, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 134, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 135, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 136, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 137, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 138, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 139, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 140, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 141, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 142, discriminator(loss: 0.012, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 143, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 144, discriminator(loss: 0.029, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 145, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 146, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 147, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 148, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 149, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 150, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 151, discriminator(loss: 0.010, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 152, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 153, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 154, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 155, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 156, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 157, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 158, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 159, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 160, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 161, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 162, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 163, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 164, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 165, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 166, discriminator(loss: 0.022, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 167, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 168, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 169, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 170, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 171, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 172, discriminator(loss: 0.065, acc.: 97.66%), generator(loss: 0.000)
# Epoch: 173, discriminator(loss: 0.016, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 174, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 175, discriminator(loss: 0.014, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 176, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 177, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 178, discriminator(loss: 0.022, acc.: 98.44%), generator(loss: 0.001)
# Epoch: 179, discriminator(loss: 0.012, acc.: 100.00%), generator(loss: 0.002)
# Epoch: 180, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 181, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.002)
# Epoch: 182, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 0.003)
# Epoch: 183, discriminator(loss: 0.017, acc.: 99.22%), generator(loss: 0.011)
# Epoch: 184, discriminator(loss: 0.033, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 185, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.014)
# Epoch: 186, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.032)
# Epoch: 187, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.010)
# Epoch: 188, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.008)
# Epoch: 189, discriminator(loss: 0.007, acc.: 100.00%), generator(loss: 0.011)
# Epoch: 190, discriminator(loss: 0.026, acc.: 99.22%), generator(loss: 0.006)
# Epoch: 191, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.002)
# Epoch: 192, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.003)
# Epoch: 193, discriminator(loss: 0.012, acc.: 99.22%), generator(loss: 0.004)
# Epoch: 194, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.003)
# Epoch: 195, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.002)
# Epoch: 196, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.006)
# Epoch: 197, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.009)
# Epoch: 198, discriminator(loss: 0.008, acc.: 100.00%), generator(loss: 0.014)
# Epoch: 199, discriminator(loss: 0.006, acc.: 100.00%), generator(loss: 0.009)
# Epoch: 200, discriminator(loss: 0.005, acc.: 100.00%), generator(loss: 0.011)
# Epoch: 201, discriminator(loss: 0.014, acc.: 99.22%), generator(loss: 0.001)
# Epoch: 202, discriminator(loss: 0.004, acc.: 100.00%), generator(loss: 0.005)
# Epoch: 203, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.004)
# Epoch: 204, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 205, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 206, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 207, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 208, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 209, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 210, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 211, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 212, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 213, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 214, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 215, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 216, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 217, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 218, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 219, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 220, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 221, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 222, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 223, discriminator(loss: 0.007, acc.: 99.22%), generator(loss: 0.000)
# Epoch: 224, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 225, discriminator(loss: 0.003, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 226, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 227, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 228, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 229, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 230, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 231, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 232, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 233, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 234, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 235, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 236, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 237, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 238, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 239, discriminator(loss: 0.002, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 240, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 241, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 242, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 243, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 244, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 245, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 246, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 247, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 248, discriminator(loss: 0.001, acc.: 100.00%), generator(loss: 0.000)
# Epoch: 249, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# Epoch: 250, discriminator(loss: 0.000, acc.: 100.00%), generator(loss: 0.001)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\api\_v1\keras\layers\__init__.py in <module>
#      57
#      58     dis_loss_real = discriminator.train_on_batch(imgs_real, np.ones((batch_size,1)))
# ---> 59     dis_loss_fake = discriminator.train_on_batch(imgs_fake, np.zeros((batch_size,1)))
#      60     dis_loss = np.add(dis_loss_real,dis_loss_fake)*0.5
#      61
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
(2,2)+(3,)
# Out:
# (2, 2, 3)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Reshape, Dense

def image_generation(x_test, W1, W2, W3, B1, B2, B3):
    y_predict = np.zeros((100,14,14))
    ### START YOUR CODE HERE ###
    
    img_shape=(14,14)
    generator = Sequential()
    
    generator.add(Dense(64,activation='relu',input_dim=32))    
    generator.add(Dense(128,activation='relu'))
    generator.add(Dense(np.prod(img_shape), activation='tanh'))
    generator.add(Reshape(img_shape))
    
    generator.layers[0].set_weights([W1,B1])
    generator.layers[1].set_weights([W2,B2])
    generator.layers[2].set_weights([W3,B3])
    
    y_predict=generator.predict(x_test)
      
    
    #### END YOUR CODE HERE ####
    return y_predict

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Reshape, Dense

def image_discrimination(x_train, x_test, W1, W2, W3, W4, W5, B1, B2, B3, B4, B5):
    score = np.zeros((2,100))
    ### START YOUR CODE HERE ###
    
    y_predict = np.zeros((100,14,14))   
    img_shape=(14,14)
    generator = Sequential()
    
    generator.add(Dense(64,activation='relu',input_dim=32))    
    generator.add(Dense(128,activation='relu'))
    generator.add(Dense(np.prod(img_shape), activation='tanh'))
    generator.add(Reshape(img_shape))
    
    generator.layers[0].set_weights([W1,B1])
    generator.layers[1].set_weights([W2,B2])
    generator.layers[2].set_weights([W3,B3])
    y_predict=generator.predict(x_test)
    
    
    discriminator = Sequential()
    discriminator.add(Reshape((np.prod(img_shape),),input_shape=img_shape))
    discriminator.add(Dense(64,activation='relu'))
    discriminator.add(Dense(1, activation='sigmoid'))

    discriminator.layers[1].set_weights([W4,B4])
    discriminator.layers[2].set_weights([W5,B5])
    
    score[0]=discriminator.predict(y_predict)[:,0]
    score[1]=discriminator.predict(x_train)[:,0]
    
    
    
    #### END YOUR CODE HERE ####
    return score

# %%
np.prod((14,14))
# Out:
# 196

# %%
np.prod(img_shape)
# Out:
# 2304

# %%
np.array([[1],[0],[11],[10],[9],[5]])[:,0]
# Out:
# array([ 1,  0, 11, 10,  9,  5])

# %%
np.array([[1],[0],[11],[10],[9],[5]])
# Out:
# array([[ 1],
#        [ 0],
#        [11],
#        [10],
#        [ 9],
#        [ 5]])

# %%
A=np.array([[1],[0],[11],[10],[9],[5]])

# %%
#HW1

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Reshape, Dense

def image_generation(x_test, W1, W2, W3, B1, B2, B3):
    y_predict = np.zeros((100,14,14))
    ### START YOUR CODE HERE ###
    
    img_shape=(14,14)
    generator = Sequential()
    
    generator.add(Dense(64,activation='relu',input_dim=32))    
    generator.add(Dense(128,activation='relu'))
    generator.add(Dense(np.prod(img_shape), activation='tanh'))
    generator.add(Reshape(img_shape))
    
    generator.layers[0].set_weights([W1,B1])
    generator.layers[1].set_weights([W2,B2])
    generator.layers[2].set_weights([W3,B3])
    
    y_predict=generator.predict(x_test)
      
    
    #### END YOUR CODE HERE ####
    return y_predict

# %%
#HW2

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Reshape, Dense

def image_discrimination(x_train, x_test, W1, W2, W3, W4, W5, B1, B2, B3, B4, B5):
    score = np.zeros((2,100))
    ### START YOUR CODE HERE ###
    
    y_predict = np.zeros((100,14,14))   
    img_shape=(14,14)
    generator = Sequential()
    
    generator.add(Dense(64,activation='relu',input_dim=32))    
    generator.add(Dense(128,activation='relu'))
    generator.add(Dense(np.prod(img_shape), activation='tanh'))
    generator.add(Reshape(img_shape))
    
    generator.layers[0].set_weights([W1,B1])
    generator.layers[1].set_weights([W2,B2])
    generator.layers[2].set_weights([W3,B3])
    y_predict=generator.predict(x_test)
    
    
    discriminator = Sequential()
    discriminator.add(Reshape((np.prod(img_shape),),input_shape=img_shape))
    discriminator.add(Dense(64,activation='relu'))
    discriminator.add(Dense(1, activation='sigmoid'))

    discriminator.layers[1].set_weights([W4,B4])
    discriminator.layers[2].set_weights([W5,B5])
    
    score[0]=discriminator.predict(y_predict)[:,0]
    score[1]=discriminator.predict(x_train)[:,0]
    
    
    
    #### END YOUR CODE HERE ####
    return score
